# %% [markdown]
# # Input setup

# %%
import torch
import cv2
import numpy as np

cap = cv2.VideoCapture('./testVideos/vid2.mp4')
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# %% [markdown]
# # YOLO

# %%
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in /Users/vatsal007/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-3-10 Python-3.8.16 torch-2.1.0.dev20230302 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# # DeepSort

# %%
from deep_sort_realtime.deepsort_tracker import DeepSort
from deep_sort.deep_sort import nn_matching
from deep_sort.deep_sort.detection import Detection
from deep_sort.deep_sort.tracker import Tracker
from deep_sort.tools import generate_detections
from deep_sort.application_util import preprocessing

# Set up the DeepSORT tracker
max_cosine_distance = 0.1
nn_budget = None
nms_max_overlap = 1.0

model_filename = './deep_sort/model_data/mars-small128.pb'
encoder = generate_detections.create_box_encoder(model_filename, batch_size=1)
metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
tracker = Tracker(metric)
# Out:
# WARNING:tensorflow:From /Users/vatsal007/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-03-22 19:42:03.032742: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-22 19:42:03.033150: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# # Detection and Display

# %%
import time
start_time = time.time()
num_frames = 0

ids = []
while(cap.isOpened()):
      
# Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        # Increment the frame count
        num_frames += 1
        # Calculate fps
        elapsed_time = time.time() - start_time
        fps = num_frames / elapsed_time
        # Display the fps
        cv2.putText(frame, f"FPS: {round(fps, 2)}", (20, 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
        #detecting any object
        img = []
        img.append(frame)
        result = model(img).pandas().xyxy[0]
        yoloout = result

        # vehicles = []

        #converting output to deepsort input
        boxes, scores, classes, detections = [],[],[],[]
        for i in result.index:
            if(result['name'][i] == 'car' or result['name'][i] == 'truck' or result['name'][i] == 'motorcycle' or result['name'][i] == 'bicycle'):
                classes.append(result['name'][i])
                scores.append(result['confidence'][i])
                xleft,yleft,xright,yright = int(result['xmin'][i]),int(result['ymin'][i]),int(result['xmax'][i]),int(result['ymax'][i])
                bbox = [xleft, yleft, xright-xleft, yright-yleft]
                boxes.append(bbox)
        classes = np.array(classes)
        scores = np.array(scores)
        boxes = np.array(boxes)
        features = np.array(encoder(frame,boxes))
        detections = [Detection(bbox,score,feature) for bbox, score, class_name, feature in zip(boxes, scores, classes, features)]

        boxes = np.array([detection.tlwh for detection in detections])
        scores = np.array(detection.confidence for detection in detections)

        # indices = preprocessing.non_max_suppression(boxes, nms_max_overlap,scores)
        # detections = [detections[i] for i in indices]

        # Update the tracker with the current detections
        tracker.predict()
        tracker.update(detections)

        for track in tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue
            bbox = track.to_tlbr()
            ids.append(track.track_id)
            cv2.rectangle(frame, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (255,0,0), 2)
            cv2.putText(frame, str(track.track_id), (int(bbox[0]), int(bbox[1]) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)


        cv2.putText(frame, "Total Cars: "+str(len(set(ids))), (10,10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)
        cv2.imshow('Frame', frame)
            

    # Press Q on keyboard to exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
  
# Break the loop
    else:
        break
# Out:
# 1   HIToolbox                           0x0000000191eb85c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x0000000191e82478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x000000018d395214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000018d393e10 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x000000018d6bba9c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x000000018d4bcfb0 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x0000000191e50b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x0000000191e50ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x0000000188795410 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x0000000188765f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x0000000188765eb8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x00000001887648a4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x0000000188763878 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x0000000191e43fa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x0000000191e43c30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x0000000191e43b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x000000018b9e984c _DPSNextEvent + 632
# 18  AppKit                              0x000000018b9e89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x0000000167080ad0 cvWaitKey + 344
# 20  cv2.abi3.so                         0x000000016707ac08 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x000000016707ad00 _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x00000001663e114c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.8                           0x000000010238c3e0 cfunction_call_varargs + 288
# 24  python3.8                           0x000000010238baf0 _PyObject_MakeTpCall + 744
# 25  python3.8                           0x0000000102478158 call_function + 612
# 26  python3.8                           0x000000010247483c _PyEval_EvalFrameDefault + 27176
# 27  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 28  python3.8                           0x000000010246cc30 PyEval_EvalCode + 60
# 29  python3.8                           0x0000000102468fa0 builtin_exec + 900
# 30  python3.8                           0x00000001023d95c0 cfunction_vectorcall_FASTCALL + 284
# 31  python3.8                           0x00000001024780c0 call_function + 460
# 32  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 33  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 34  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 35  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 36  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 37  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 38  python3.8                           0x0000000102399444 method_vectorcall_O + 448
# 39  python3.8                           0x00000001024780c0 call_function + 460
# 40  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 41  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 42  python3.8                           0x00000001024780c0 call_function + 460
# 43  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 44  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 45  python3.8                           0x00000001024780c0 call_function + 460
# 46  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 47  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 48  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 49  python3.8                           0x000000010238fea4 method_vectorcall + 520
# 50  python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 51  python3.8                           0x0000000102474af0 _PyEval_EvalFrameDefault + 27868
# 52  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 53  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 54  python3.8                           0x000000010238fd38 method_vectorcall + 156
# 55  python3.8                           0x00000001024780c0 call_function + 460
# 56  python3.8                           0x0000000102474934 _PyEval_EvalFrameDefault + 27424
# 57  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 58  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 59  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 60  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 61  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 62  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 63  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 64  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 65  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 66  _asyncio.cpython-38-darwin.so       0x0000000103c03db4 task_step + 680
# 67  _asyncio.cpython-38-darwin.so       0x0000000103c03940 TaskWakeupMethWrapper_call + 248
# 68  python3.8                           0x000000010238baf0 _PyObject_MakeTpCall + 744
# 69  python3.8                           0x000000010248ccd8 context_run + 328
# 70  python3.8                           0x00000001023d96ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 71  python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 72  python3.8                           0x0000000102474cb4 _PyEval_EvalFrameDefault + 28320
# 73  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 74  python3.8                           0x00000001024780c0 call_function + 460
# 75  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 76  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 77  python3.8                           0x00000001024780c0 call_function + 460
# 78  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 79  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 80  python3.8                           0x00000001024780c0 call_function + 460
# 81  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 82  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 83  python3.8                           0x00000001024780c0 call_function + 460
# 84  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 85  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 86  python3.8                           0x00000001024780c0 call_function + 460
# 87  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 88  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 89  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 90  python3.8                           0x000000010238fd38 method_vectorcall + 156
# 91  python3.8                           0x00000001024780c0 call_function + 460
# 92  python3.8                           0x000000010247483c _PyEval_EvalFrameDefault + 27176
# 93  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 94  python3.8                           0x000000010246cc30 PyEval_EvalCode + 60
# 95  python3.8                           0x0000000102468fa0 builtin_exec + 900
# 96  python3.8                           0x00000001023d95c0 cfunction_vectorcall_FASTCALL + 284
# 97  python3.8                           0x00000001024780c0 call_function + 460
# 98  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 99  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 100 python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 101 python3.8                           0x00000001024780c0 call_function + 460
# 102 python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 103 python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 104 python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 105 python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 106 python3.8                           0x00000001024e11b8 pymain_run_module + 240
# 107 python3.8                           0x00000001024e0928 Py_RunMain + 1616
# 108 python3.8                           0x00000001024e1c50 pymain_main + 1220
# 109 python3.8                           0x0000000102366084 main + 56
# 110 dyld                                0x000000018835be50 start + 2544
# 1   HIToolbox                           0x0000000191e4390c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x0000000191e82478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x000000018d395214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000018d393e10 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x000000018d6bba9c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x000000018d4bcfb0 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x0000000191e50b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x0000000191e50ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x0000000188795410 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x0000000188765f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x0000000188765eb8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x00000001887648a4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x0000000188763878 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x0000000191e43fa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x0000000191e43c30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x0000000191e43b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x000000018b9e984c _DPSNextEvent + 632
# 18  AppKit                              0x000000018b9e89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x0000000167080ad0 cvWaitKey + 344
# 20  cv2.abi3.so                         0x000000016707ac08 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x000000016707ad00 _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x00000001663e114c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.8                           0x000000010238c3e0 cfunction_call_varargs + 288
# 24  python3.8                           0x000000010238baf0 _PyObject_MakeTpCall + 744
# 25  python3.8                           0x0000000102478158 call_function + 612
# 26  python3.8                           0x000000010247483c _PyEval_EvalFrameDefault + 27176
# 27  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 28  python3.8                           0x000000010246cc30 PyEval_EvalCode + 60
# 29  python3.8                           0x0000000102468fa0 builtin_exec + 900
# 30  python3.8                           0x00000001023d95c0 cfunction_vectorcall_FASTCALL + 284
# 31  python3.8                           0x00000001024780c0 call_function + 460
# 32  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 33  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 34  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 35  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 36  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 37  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 38  python3.8                           0x0000000102399444 method_vectorcall_O + 448
# 39  python3.8                           0x00000001024780c0 call_function + 460
# 40  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 41  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 42  python3.8                           0x00000001024780c0 call_function + 460
# 43  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 44  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 45  python3.8                           0x00000001024780c0 call_function + 460
# 46  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 47  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 48  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 49  python3.8                           0x000000010238fea4 method_vectorcall + 520
# 50  python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 51  python3.8                           0x0000000102474af0 _PyEval_EvalFrameDefault + 27868
# 52  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 53  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 54  python3.8                           0x000000010238fd38 method_vectorcall + 156
# 55  python3.8                           0x00000001024780c0 call_function + 460
# 56  python3.8                           0x0000000102474934 _PyEval_EvalFrameDefault + 27424
# 57  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 58  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 59  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 60  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 61  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 62  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 63  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 64  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 65  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 66  _asyncio.cpython-38-darwin.so       0x0000000103c03db4 task_step + 680
# 67  _asyncio.cpython-38-darwin.so       0x0000000103c03940 TaskWakeupMethWrapper_call + 248
# 68  python3.8                           0x000000010238baf0 _PyObject_MakeTpCall + 744
# 69  python3.8                           0x000000010248ccd8 context_run + 328
# 70  python3.8                           0x00000001023d96ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 71  python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 72  python3.8                           0x0000000102474cb4 _PyEval_EvalFrameDefault + 28320
# 73  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 74  python3.8                           0x00000001024780c0 call_function + 460
# 75  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 76  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 77  python3.8                           0x00000001024780c0 call_function + 460
# 78  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 79  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 80  python3.8                           0x00000001024780c0 call_function + 460
# 81  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 82  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 83  python3.8                           0x00000001024780c0 call_function + 460
# 84  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 85  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 86  python3.8                           0x00000001024780c0 call_function + 460
# 87  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 88  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 89  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 90  python3.8                           0x000000010238fd38 method_vectorcall + 156
# 91  python3.8                           0x00000001024780c0 call_function + 460
# 92  python3.8                           0x000000010247483c _PyEval_EvalFrameDefault + 27176
# 93  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 94  python3.8                           0x000000010246cc30 PyEval_EvalCode + 60
# 95  python3.8                           0x0000000102468fa0 builtin_exec + 900
# 96  python3.8                           0x00000001023d95c0 cfunction_vectorcall_FASTCALL + 284
# 97  python3.8                           0x00000001024780c0 call_function + 460
# 98  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 99  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 100 python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 101 python3.8                           0x00000001024780c0 call_function + 460
# 102 python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 103 python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 104 python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 105 python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 106 python3.8                           0x00000001024e11b8 pymain_run_module + 240
# 107 python3.8                           0x00000001024e0928 Py_RunMain + 1616
# 108 python3.8                           0x00000001024e1c50 pymain_main + 1220
# 109 python3.8                           0x0000000102366084 main + 56
# 110 dyld                                0x000000018835be50 start + 2544
# 1   HIToolbox                           0x0000000191eb85c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x0000000191e82478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x000000018d395214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000018d393e10 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x000000018d6bba9c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x000000018d4bcfb0 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x0000000191e50b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x0000000191e50ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x0000000188795410 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x0000000188765f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x0000000188765eb8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x00000001887648a4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x0000000188763878 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x0000000191e43fa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x0000000191e43c30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x0000000191e43b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x000000018b9e984c _DPSNextEvent + 632
# 18  AppKit                              0x000000018b9e89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x0000000167080ad0 cvWaitKey + 344
# 20  cv2.abi3.so                         0x000000016707ac08 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x000000016707ad00 _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x00000001663e114c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.8                           0x000000010238c3e0 cfunction_call_varargs + 288
# 24  python3.8                           0x000000010238baf0 _PyObject_MakeTpCall + 744
# 25  python3.8                           0x0000000102478158 call_function + 612
# 26  python3.8                           0x000000010247483c _PyEval_EvalFrameDefault + 27176
# 27  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 28  python3.8                           0x000000010246cc30 PyEval_EvalCode + 60
# 29  python3.8                           0x0000000102468fa0 builtin_exec + 900
# 30  python3.8                           0x00000001023d95c0 cfunction_vectorcall_FASTCALL + 284
# 31  python3.8                           0x00000001024780c0 call_function + 460
# 32  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 33  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 34  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 35  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 36  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 37  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 38  python3.8                           0x0000000102399444 method_vectorcall_O + 448
# 39  python3.8                           0x00000001024780c0 call_function + 460
# 40  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 41  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 42  python3.8                           0x00000001024780c0 call_function + 460
# 43  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 44  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 45  python3.8                           0x00000001024780c0 call_function + 460
# 46  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 47  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 48  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 49  python3.8                           0x000000010238fea4 method_vectorcall + 520
# 50  python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 51  python3.8                           0x0000000102474af0 _PyEval_EvalFrameDefault + 27868
# 52  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 53  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 54  python3.8                           0x000000010238fd38 method_vectorcall + 156
# 55  python3.8                           0x00000001024780c0 call_function + 460
# 56  python3.8                           0x0000000102474934 _PyEval_EvalFrameDefault + 27424
# 57  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 58  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 59  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 60  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 61  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 62  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 63  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 64  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 65  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 66  _asyncio.cpython-38-darwin.so       0x0000000103c03db4 task_step + 680
# 67  _asyncio.cpython-38-darwin.so       0x0000000103c03940 TaskWakeupMethWrapper_call + 248
# 68  python3.8                           0x000000010238baf0 _PyObject_MakeTpCall + 744
# 69  python3.8                           0x000000010248ccd8 context_run + 328
# 70  python3.8                           0x00000001023d96ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 71  python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 72  python3.8                           0x0000000102474cb4 _PyEval_EvalFrameDefault + 28320
# 73  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 74  python3.8                           0x00000001024780c0 call_function + 460
# 75  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 76  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 77  python3.8                           0x00000001024780c0 call_function + 460
# 78  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 79  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 80  python3.8                           0x00000001024780c0 call_function + 460
# 81  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 82  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 83  python3.8                           0x00000001024780c0 call_function + 460
# 84  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 85  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 86  python3.8                           0x00000001024780c0 call_function + 460
# 87  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 88  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 89  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 90  python3.8                           0x000000010238fd38 method_vectorcall + 156
# 91  python3.8                           0x00000001024780c0 call_function + 460
# 92  python3.8                           0x000000010247483c _PyEval_EvalFrameDefault + 27176
# 93  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 94  python3.8                           0x000000010246cc30 PyEval_EvalCode + 60
# 95  python3.8                           0x0000000102468fa0 builtin_exec + 900
# 96  python3.8                           0x00000001023d95c0 cfunction_vectorcall_FASTCALL + 284
# 97  python3.8                           0x00000001024780c0 call_function + 460
# 98  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 99  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 100 python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 101 python3.8                           0x00000001024780c0 call_function + 460
# 102 python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 103 python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 104 python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 105 python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 106 python3.8                           0x00000001024e11b8 pymain_run_module + 240
# 107 python3.8                           0x00000001024e0928 Py_RunMain + 1616
# 108 python3.8                           0x00000001024e1c50 pymain_main + 1220
# 109 python3.8                           0x0000000102366084 main + 56
# 110 dyld                                0x000000018835be50 start + 2544
# 1   HIToolbox                           0x0000000191e4390c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x0000000191e82478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x000000018d395214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000018d393e10 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x000000018d6bba9c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x000000018d4bcfb0 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x0000000191e50b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x0000000191e50ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x0000000188795410 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x0000000188765f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x0000000188765eb8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x00000001887648a4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x0000000188763878 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x0000000191e43fa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x0000000191e43c30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x0000000191e43b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x000000018b9e984c _DPSNextEvent + 632
# 18  AppKit                              0x000000018b9e89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x0000000167080ad0 cvWaitKey + 344
# 20  cv2.abi3.so                         0x000000016707ac08 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x000000016707ad00 _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x00000001663e114c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.8                           0x000000010238c3e0 cfunction_call_varargs + 288
# 24  python3.8                           0x000000010238baf0 _PyObject_MakeTpCall + 744
# 25  python3.8                           0x0000000102478158 call_function + 612
# 26  python3.8                           0x000000010247483c _PyEval_EvalFrameDefault + 27176
# 27  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 28  python3.8                           0x000000010246cc30 PyEval_EvalCode + 60
# 29  python3.8                           0x0000000102468fa0 builtin_exec + 900
# 30  python3.8                           0x00000001023d95c0 cfunction_vectorcall_FASTCALL + 284
# 31  python3.8                           0x00000001024780c0 call_function + 460
# 32  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 33  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 34  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 35  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 36  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 37  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 38  python3.8                           0x0000000102399444 method_vectorcall_O + 448
# 39  python3.8                           0x00000001024780c0 call_function + 460
# 40  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 41  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 42  python3.8                           0x00000001024780c0 call_function + 460
# 43  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 44  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 45  python3.8                           0x00000001024780c0 call_function + 460
# 46  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 47  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 48  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 49  python3.8                           0x000000010238fea4 method_vectorcall + 520
# 50  python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 51  python3.8                           0x0000000102474af0 _PyEval_EvalFrameDefault + 27868
# 52  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 53  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 54  python3.8                           0x000000010238fd38 method_vectorcall + 156
# 55  python3.8                           0x00000001024780c0 call_function + 460
# 56  python3.8                           0x0000000102474934 _PyEval_EvalFrameDefault + 27424
# 57  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 58  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 59  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 60  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 61  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 62  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 63  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 64  python3.8                           0x00000001024708b4 _PyEval_EvalFrameDefault + 10912
# 65  python3.8                           0x00000001023a2254 gen_send_ex + 288
# 66  _asyncio.cpython-38-darwin.so       0x0000000103c03db4 task_step + 680
# 67  _asyncio.cpython-38-darwin.so       0x0000000103c03940 TaskWakeupMethWrapper_call + 248
# 68  python3.8                           0x000000010238baf0 _PyObject_MakeTpCall + 744
# 69  python3.8                           0x000000010248ccd8 context_run + 328
# 70  python3.8                           0x00000001023d96ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 71  python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 72  python3.8                           0x0000000102474cb4 _PyEval_EvalFrameDefault + 28320
# 73  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 74  python3.8                           0x00000001024780c0 call_function + 460
# 75  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 76  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 77  python3.8                           0x00000001024780c0 call_function + 460
# 78  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 79  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 80  python3.8                           0x00000001024780c0 call_function + 460
# 81  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 82  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 83  python3.8                           0x00000001024780c0 call_function + 460
# 84  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 85  python3.8                           0x000000010238c7b4 function_code_fastcall + 128
# 86  python3.8                           0x00000001024780c0 call_function + 460
# 87  python3.8                           0x0000000102474818 _PyEval_EvalFrameDefault + 27140
# 88  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 89  python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 90  python3.8                           0x000000010238fd38 method_vectorcall + 156
# 91  python3.8                           0x00000001024780c0 call_function + 460
# 92  python3.8                           0x000000010247483c _PyEval_EvalFrameDefault + 27176
# 93  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 94  python3.8                           0x000000010246cc30 PyEval_EvalCode + 60
# 95  python3.8                           0x0000000102468fa0 builtin_exec + 900
# 96  python3.8                           0x00000001023d95c0 cfunction_vectorcall_FASTCALL + 284
# 97  python3.8                           0x00000001024780c0 call_function + 460
# 98  python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 99  python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 100 python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 101 python3.8                           0x00000001024780c0 call_function + 460
# 102 python3.8                           0x00000001024748b8 _PyEval_EvalFrameDefault + 27300
# 103 python3.8                           0x000000010246d7fc _PyEval_EvalCodeWithName + 3008
# 104 python3.8                           0x000000010238c918 _PyFunction_Vectorcall + 208
# 105 python3.8                           0x000000010238bfd8 PyVectorcall_Call + 120
# 106 python3.8                           0x00000001024e11b8 pymain_run_module + 240
# 107 python3.8                           0x00000001024e0928 Py_RunMain + 1616
# 108 python3.8                           0x00000001024e1c50 pymain_main + 1220
# 109 python3.8                           0x0000000102366084 main + 56
# 110 dyld                                0x000000018835be50 start + 2544
