# %% [markdown]
# # Input setup

# %%
import torch
import torchvision
import torchvision.transforms as T
import cv2
import numpy as np
import pandas as pd

cap = cv2.VideoCapture('./testVideos/vid2.mp4')
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# %% [markdown]
# # FasterRCNN

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
transform = T.Compose([T.ToTensor(), T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# weights (COCOv1 dataset trained)
weights=torchvision.models.detection.faster_rcnn.FasterRCNN_ResNet50_FPN_V2_Weights.DEFAULT
# model
model = torchvision.models.detection.fasterrcnn_resnet50_fpn_v2(weights)
model = model.to(device)
model.eval()
# Out:
# /Users/vatsal007/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-3): 4 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): FastRCNNConvFCHead(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (4): Flatten(start_dim=1, end_dim=-1)
#       (5): Linear(in_features=12544, out_features=1024, bias=True)
#       (6): ReLU(inplace=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#   )
# )

# %% [markdown]
# # DeepSort

# %%
from deep_sort_realtime.deepsort_tracker import DeepSort
from deep_sort.deep_sort import nn_matching
from deep_sort.deep_sort.detection import Detection
from deep_sort.deep_sort.tracker import Tracker
from deep_sort.tools import generate_detections
from deep_sort.application_util import preprocessing

# Set up the DeepSORT tracker
max_cosine_distance = 0.1
nn_budget = None
nms_max_overlap = 1.0

model_filename = './deep_sort/model_data/mars-small128.pb'
encoder = generate_detections.create_box_encoder(model_filename, batch_size=1)
metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
tracker = Tracker(metric)
# Out:
# WARNING:tensorflow:From /Users/vatsal007/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-03-22 21:57:21.366227: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-22 21:57:21.366673: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# # Detection and Display

# %%
import time
start_time = time.time()
num_frames = 0

ids = []

while(cap.isOpened()):
      
# Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        # Increment the frame count
        num_frames += 1
        # Calculate fps
        elapsed_time = time.time() - start_time
        fps = num_frames / elapsed_time
        # Display the fps
        cv2.putText(frame, f"FPS: {round(fps, 2)}", (20, 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
        #detecting any object using FasterRCNN
        img = transform(frame).to(device)
        with torch.no_grad():
            result = model([img])[0]

        totaldetections = len(np.array(result['boxes'].to('cpu')))

        #converting output to deepsort input
        boxes, scores, classes, detections = [],[],[],[]
        for i in range(totaldetections):
            label = np.array(result['labels'].to('cpu'))[i]
            score = np.array(result['scores'].to('cpu'))[i]
            bbox = np.array(result['boxes'].to('cpu'))[i]

            # if(result['name'][i] == 'car' or result['name'][i] == 'truck' or result['name'][i] == 'motorcycle' or result['name'][i] == 'bicycle'):
            if(label == 3 or label == 8):
                classes.append('cars')
                scores.append(score)
                bbox = [bbox[0],bbox[1],bbox[2]-bbox[0],bbox[3]-bbox[1]]
                boxes.append(bbox)

        classes = np.array(classes)
        scores = np.array(scores)
        boxes = np.array(boxes)
        features = np.array(encoder(frame,boxes))
        detections = [Detection(bbox,score,feature) for bbox, score, class_name, feature in zip(boxes, scores, classes, features)]

        boxes = np.array([detection.tlwh for detection in detections])
        scores = np.array(detection.confidence for detection in detections)

        # indices = preprocessing.non_max_suppression(boxes, nms_max_overlap,scores)
        # detections = [detections[i] for i in indices]

        # Update the tracker with the current detections
        tracker.predict()
        tracker.update(detections)

        for track in tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue
            bbox = track.to_tlbr()
            ids.append(track.track_id)
            cv2.rectangle(frame, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (255,0,0), 2)
            cv2.putText(frame, str(track.track_id), (int(bbox[0]), int(bbox[1]) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)

        cv2.putText(frame, "Total Cars: "+str(len(set(ids))), (10,10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)
        cv2.imshow('Frame', frame)
            

    # Press Q on keyboard to exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
  
# Break the loop
    else:
        break
# Out:
# 2023-03-22 21:57:31.577676: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# 2023-03-22 21:57:31.587453: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-22 21:57:31.596608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1   HIToolbox                           0x00000001a3fa85c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001a3fa8188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x00000001a3f4b310 SetMenuBarObscured + 372
# 4   HIToolbox                           0x00000001a3f4aee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 5   HIToolbox                           0x00000001a3f44fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 6   HIToolbox                           0x00000001a3f0bcd0 _NotifyEventLoopObservers + 176
# 7   HIToolbox                           0x00000001a3f4496c AcquireEventFromQueue + 432
# 8   HIToolbox                           0x00000001a3f33e0c ReceiveNextEventCommon + 712
# 9   HIToolbox                           0x00000001a3f33b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 10  AppKit                              0x000000019dad984c _DPSNextEvent + 632
# 11  AppKit                              0x000000019dad89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 12  cv2.abi3.so                         0x000000013c780ad0 cvWaitKey + 344
# 13  cv2.abi3.so                         0x000000013c77ac08 _ZN2cv9waitKeyExEi + 168
# 14  cv2.abi3.so                         0x000000013c77ad00 _ZN2cv7waitKeyEi + 48
# 15  cv2.abi3.so                         0x000000013bae114c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  python3.8                           0x00000001027a43e0 cfunction_call_varargs + 288
# 17  python3.8                           0x00000001027a3af0 _PyObject_MakeTpCall + 744
# 18  python3.8                           0x0000000102890158 call_function + 612
# 19  python3.8                           0x000000010288c83c _PyEval_EvalFrameDefault + 27176
# 20  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 21  python3.8                           0x0000000102884c30 PyEval_EvalCode + 60
# 22  python3.8                           0x0000000102880fa0 builtin_exec + 900
# 23  python3.8                           0x00000001027f15c0 cfunction_vectorcall_FASTCALL + 284
# 24  python3.8                           0x00000001028900c0 call_function + 460
# 25  python3.8                           0x000000010288c8b8 _PyEval_EvalFrameDefault + 27300
# 26  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 27  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 28  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 29  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 30  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 31  python3.8                           0x00000001027b1444 method_vectorcall_O + 448
# 32  python3.8                           0x00000001028900c0 call_function + 460
# 33  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 34  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 35  python3.8                           0x00000001028900c0 call_function + 460
# 36  python3.8                           0x000000010288c8b8 _PyEval_EvalFrameDefault + 27300
# 37  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 38  python3.8                           0x00000001028900c0 call_function + 460
# 39  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 40  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 41  python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 42  python3.8                           0x00000001027a7ea4 method_vectorcall + 520
# 43  python3.8                           0x00000001027a3fd8 PyVectorcall_Call + 120
# 44  python3.8                           0x000000010288caf0 _PyEval_EvalFrameDefault + 27868
# 45  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 46  python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 47  python3.8                           0x00000001027a7d38 method_vectorcall + 156
# 48  python3.8                           0x00000001028900c0 call_function + 460
# 49  python3.8                           0x000000010288c934 _PyEval_EvalFrameDefault + 27424
# 50  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 51  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 52  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 53  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 54  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 55  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 56  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 57  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 58  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 59  _asyncio.cpython-38-darwin.so       0x0000000103707db4 task_step + 680
# 60  _asyncio.cpython-38-darwin.so       0x0000000103707940 TaskWakeupMethWrapper_call + 248
# 61  python3.8                           0x00000001027a3af0 _PyObject_MakeTpCall + 744
# 62  python3.8                           0x00000001028a4cd8 context_run + 328
# 63  python3.8                           0x00000001027f16ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 64  python3.8                           0x00000001027a3fd8 PyVectorcall_Call + 120
# 65  python3.8                           0x000000010288ccb4 _PyEval_EvalFrameDefault + 28320
# 66  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 67  python3.8                           0x00000001028900c0 call_function + 460
# 68  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 69  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 70  python3.8                           0x00000001028900c0 call_function + 460
# 71  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 72  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 73  python3.8                           0x00000001028900c0 call_function + 460
# 74  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 75  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 76  python3.8                           0x00000001028900c0 call_function + 460
# 77  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 78  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 79  python3.8                           0x00000001028900c0 call_function + 460
# 80  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 81  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 82  python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 83  python3.8                           0x00000001027a7d38 method_vectorcall + 156
# 84  python3.8                           0x00000001028900c0 call_function + 460
# 85  python3.8                           0x000000010288c83c _PyEval_EvalFrameDefault + 27176
# 86  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 87  python3.8                           0x0000000102884c30 PyEval_EvalCode + 60
# 88  python3.8                           0x0000000102880fa0 builtin_exec + 900
# 89  python3.8                           0x00000001027f15c0 cfunction_vectorcall_FASTCALL + 284
# 90  python3.8                           0x00000001028900c0 call_function + 460
# 91  python3.8                           0x000000010288c8b8 _PyEval_EvalFrameDefault + 27300
# 92  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 93  python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 94  python3.8                           0x00000001028900c0 call_function + 460
# 95  python3.8                           0x000000010288c8b8 _PyEval_EvalFrameDefault + 27300
# 96  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 97  python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 98  python3.8                           0x00000001027a3fd8 PyVectorcall_Call + 120
# 99  python3.8                           0x00000001028f91b8 pymain_run_module + 240
# 100 python3.8                           0x00000001028f8928 Py_RunMain + 1616
# 101 python3.8                           0x00000001028f9c50 pymain_main + 1220
# 102 python3.8                           0x000000010277e084 main + 56
# 103 dyld                                0x000000019a44be50 start + 2544
# 1   HIToolbox                           0x00000001a3f3390c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x00000001a3f72478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x000000019f485214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000019f483e10 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x000000019f7aba9c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x000000019f5acfb0 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x00000001a3f40b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x00000001a3f40ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x000000019a885410 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x000000019a855f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x000000019a855eb8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x000000019a8548a4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x000000019a853878 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x00000001a3f33fa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00000001a3f33c30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x00000001a3f33b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x000000019dad984c _DPSNextEvent + 632
# 18  AppKit                              0x000000019dad89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x000000013c780ad0 cvWaitKey + 344
# 20  cv2.abi3.so                         0x000000013c77ac08 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x000000013c77ad00 _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x000000013bae114c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.8                           0x00000001027a43e0 cfunction_call_varargs + 288
# 24  python3.8                           0x00000001027a3af0 _PyObject_MakeTpCall + 744
# 25  python3.8                           0x0000000102890158 call_function + 612
# 26  python3.8                           0x000000010288c83c _PyEval_EvalFrameDefault + 27176
# 27  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 28  python3.8                           0x0000000102884c30 PyEval_EvalCode + 60
# 29  python3.8                           0x0000000102880fa0 builtin_exec + 900
# 30  python3.8                           0x00000001027f15c0 cfunction_vectorcall_FASTCALL + 284
# 31  python3.8                           0x00000001028900c0 call_function + 460
# 32  python3.8                           0x000000010288c8b8 _PyEval_EvalFrameDefault + 27300
# 33  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 34  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 35  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 36  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 37  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 38  python3.8                           0x00000001027b1444 method_vectorcall_O + 448
# 39  python3.8                           0x00000001028900c0 call_function + 460
# 40  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 41  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 42  python3.8                           0x00000001028900c0 call_function + 460
# 43  python3.8                           0x000000010288c8b8 _PyEval_EvalFrameDefault + 27300
# 44  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 45  python3.8                           0x00000001028900c0 call_function + 460
# 46  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 47  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 48  python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 49  python3.8                           0x00000001027a7ea4 method_vectorcall + 520
# 50  python3.8                           0x00000001027a3fd8 PyVectorcall_Call + 120
# 51  python3.8                           0x000000010288caf0 _PyEval_EvalFrameDefault + 27868
# 52  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 53  python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 54  python3.8                           0x00000001027a7d38 method_vectorcall + 156
# 55  python3.8                           0x00000001028900c0 call_function + 460
# 56  python3.8                           0x000000010288c934 _PyEval_EvalFrameDefault + 27424
# 57  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 58  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 59  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 60  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 61  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 62  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 63  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 64  python3.8                           0x00000001028888b4 _PyEval_EvalFrameDefault + 10912
# 65  python3.8                           0x00000001027ba254 gen_send_ex + 288
# 66  _asyncio.cpython-38-darwin.so       0x0000000103707db4 task_step + 680
# 67  _asyncio.cpython-38-darwin.so       0x0000000103707940 TaskWakeupMethWrapper_call + 248
# 68  python3.8                           0x00000001027a3af0 _PyObject_MakeTpCall + 744
# 69  python3.8                           0x00000001028a4cd8 context_run + 328
# 70  python3.8                           0x00000001027f16ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 71  python3.8                           0x00000001027a3fd8 PyVectorcall_Call + 120
# 72  python3.8                           0x000000010288ccb4 _PyEval_EvalFrameDefault + 28320
# 73  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 74  python3.8                           0x00000001028900c0 call_function + 460
# 75  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 76  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 77  python3.8                           0x00000001028900c0 call_function + 460
# 78  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 79  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 80  python3.8                           0x00000001028900c0 call_function + 460
# 81  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 82  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 83  python3.8                           0x00000001028900c0 call_function + 460
# 84  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 85  python3.8                           0x00000001027a47b4 function_code_fastcall + 128
# 86  python3.8                           0x00000001028900c0 call_function + 460
# 87  python3.8                           0x000000010288c818 _PyEval_EvalFrameDefault + 27140
# 88  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 89  python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 90  python3.8                           0x00000001027a7d38 method_vectorcall + 156
# 91  python3.8                           0x00000001028900c0 call_function + 460
# 92  python3.8                           0x000000010288c83c _PyEval_EvalFrameDefault + 27176
# 93  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 94  python3.8                           0x0000000102884c30 PyEval_EvalCode + 60
# 95  python3.8                           0x0000000102880fa0 builtin_exec + 900
# 96  python3.8                           0x00000001027f15c0 cfunction_vectorcall_FASTCALL + 284
# 97  python3.8                           0x00000001028900c0 call_function + 460
# 98  python3.8                           0x000000010288c8b8 _PyEval_EvalFrameDefault + 27300
# 99  python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 100 python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 101 python3.8                           0x00000001028900c0 call_function + 460
# 102 python3.8                           0x000000010288c8b8 _PyEval_EvalFrameDefault + 27300
# 103 python3.8                           0x00000001028857fc _PyEval_EvalCodeWithName + 3008
# 104 python3.8                           0x00000001027a4918 _PyFunction_Vectorcall + 208
# 105 python3.8                           0x00000001027a3fd8 PyVectorcall_Call + 120
# 106 python3.8                           0x00000001028f91b8 pymain_run_module + 240
# 107 python3.8                           0x00000001028f8928 Py_RunMain + 1616
# 108 python3.8                           0x00000001028f9c50 pymain_main + 1220
# 109 python3.8                           0x000000010277e084 main + 56
# 110 dyld                                0x000000019a44be50 start + 2544
